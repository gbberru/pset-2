# %%
import pandas as pd
import matplotlib.pyplot as plt
# Cargar los datos desde el archivo parquet

# %%
df = pd.read_parquet("yellow_tripdata_2025-01.parquet")
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.60         1.0                  N           229           237
# 1           0.50         1.0                  N           236           237
# 2           0.60         1.0                  N           141           141
# 3           0.52         1.0                  N           244           244
# 4           0.66         1.0                  N           244           116
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.isnull().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count          540149
# trip_distance                 0
# RatecodeID               540149
# store_and_fwd_flag       540149
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge     540149
# Airport_fee              540149
# cbd_congestion_fee            0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# VendorID                  0.000000
# tpep_pickup_datetime      0.000000
# tpep_dropoff_datetime     0.000000
# passenger_count          15.542845
# trip_distance             0.000000
# RatecodeID               15.542845
# store_and_fwd_flag       15.542845
# PULocationID              0.000000
# DOLocationID              0.000000
# payment_type              0.000000
# fare_amount               0.000000
# extra                     0.000000
# mta_tax                   0.000000
# tip_amount                0.000000
# tolls_amount              0.000000
# improvement_surcharge     0.000000
# total_amount              0.000000
# congestion_surcharge     15.542845
# Airport_fee              15.542845
# cbd_congestion_fee        0.000000
# dtype: float64

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# passenger_count         540149
# RatecodeID              540149
# store_and_fwd_flag      540149
# congestion_surcharge    540149
# Airport_fee             540149
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, Airport_fee, cbd_congestion_fee]
# Index: []

# %%
df[df["tpep_dropoff_datetime"] <= df["tpep_pickup_datetime"]]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 92              1  2025-01-01 00:49:48   2025-01-01 00:49:48              1.0
# 11604           1  2025-01-01 01:42:36   2025-01-01 01:42:36              1.0
# 13820           1  2025-01-01 02:13:25   2025-01-01 02:13:25              1.0
# 14605           1  2025-01-01 02:09:52   2025-01-01 02:09:52              1.0
# 14607           1  2025-01-01 02:49:40   2025-01-01 02:49:40              1.0
# ...           ...                  ...                   ...              ...
# 3450368         1  2025-01-31 10:58:58   2025-01-31 10:58:58              NaN
# 3451750         6  2025-01-31 13:01:32   2025-01-31 13:01:08              NaN
# 3455729         2  2025-01-31 17:54:00   2025-01-31 17:54:00              NaN
# 3459409         1  2025-01-31 18:55:38   2025-01-31 18:55:38              NaN
# 3475144         2  2025-01-31 23:44:00   2025-01-31 23:44:00              NaN
#
# ...

# %%
df[df["tpep_dropoff_datetime"] <= df["tpep_pickup_datetime"]]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 92              1  2025-01-01 00:49:48   2025-01-01 00:49:48              1.0
# 11604           1  2025-01-01 01:42:36   2025-01-01 01:42:36              1.0
# 13820           1  2025-01-01 02:13:25   2025-01-01 02:13:25              1.0
# 14605           1  2025-01-01 02:09:52   2025-01-01 02:09:52              1.0
# 14607           1  2025-01-01 02:49:40   2025-01-01 02:49:40              1.0
# ...           ...                  ...                   ...              ...
# 3450368         1  2025-01-31 10:58:58   2025-01-31 10:58:58              NaN
# 3451750         6  2025-01-31 13:01:32   2025-01-31 13:01:08              NaN
# 3455729         2  2025-01-31 17:54:00   2025-01-31 17:54:00              NaN
# 3459409         1  2025-01-31 18:55:38   2025-01-31 18:55:38              NaN
# 3475144         2  2025-01-31 23:44:00   2025-01-31 23:44:00              NaN
#
# ...

# %%
df[
    (df["fare_amount"] < 0) |
    (df["total_amount"] < 0) |
    (df["tip_amount"] < 0) |
    (df["tolls_amount"] < 0)
]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 17              2  2025-01-01 00:01:41   2025-01-01 00:07:14              1.0
# 22              2  2025-01-01 00:55:54   2025-01-01 01:00:38              1.0
# 104             2  2025-01-01 00:56:12   2025-01-01 01:15:00              1.0
# 149             2  2025-01-01 00:55:53   2025-01-01 01:06:49              1.0
# 202             2  2025-01-01 00:29:35   2025-01-01 00:36:02              1.0
# ...           ...                  ...                   ...              ...
# 3475198         2  2025-01-31 23:30:26   2025-01-31 23:36:41              NaN
# 3475204         2  2025-01-31 23:33:05   2025-01-31 23:46:21              NaN
# 3475205         2  2025-01-31 23:43:55   2025-01-31 23:48:40              NaN
# 3475212         2  2025-01-31 23:00:46   2025-01-31 23:12:08              NaN
# 3475217         2  2025-01-31 23:38:25   2025-01-31 23:46:15              NaN
#
# ...

# %%
df[df["passenger_count"] <= 0]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6               1  2025-01-01 00:14:47   2025-01-01 00:16:15              0.0
# 7               1  2025-01-01 00:39:27   2025-01-01 00:51:51              0.0
# 8               1  2025-01-01 00:53:43   2025-01-01 01:13:23              0.0
# 94              1  2025-01-01 00:11:27   2025-01-01 00:16:58              0.0
# 95              1  2025-01-01 00:19:30   2025-01-01 00:27:25              0.0
# ...           ...                  ...                   ...              ...
# 2933984         1  2025-01-31 23:20:45   2025-01-31 23:45:28              0.0
# 2934049         1  2025-01-31 23:54:49   2025-02-01 00:09:35              0.0
# 2934589         1  2025-01-31 23:16:04   2025-01-31 23:36:38              0.0
# 2934590         1  2025-01-31 23:57:51   2025-02-01 00:08:06              0.0
# 2934894         1  2025-01-31 23:11:52   2025-01-31 23:37:36              0.0
#
# ...

# %%
df[df["PULocationID"].isna() | df["DOLocationID"].isna()]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, Airport_fee, cbd_congestion_fee]
# Index: []

# %%
registros_erroneos = df[
    (df["tpep_dropoff_datetime"] <= df["tpep_pickup_datetime"]) |
    (df["trip_distance"] < 0) |
    (df["fare_amount"] < 0) |
    (df["total_amount"] < 0) |
    (df["tip_amount"] < 0) |
    (df["tolls_amount"] < 0) |
    (df["passenger_count"] <= 0) |
    (df["PULocationID"].isna()) |
    (df["DOLocationID"].isna())
]

registros_erroneos
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6               1  2025-01-01 00:14:47   2025-01-01 00:16:15              0.0
# 7               1  2025-01-01 00:39:27   2025-01-01 00:51:51              0.0
# 8               1  2025-01-01 00:53:43   2025-01-01 01:13:23              0.0
# 17              2  2025-01-01 00:01:41   2025-01-01 00:07:14              1.0
# 22              2  2025-01-01 00:55:54   2025-01-01 01:00:38              1.0
# ...           ...                  ...                   ...              ...
# 3475198         2  2025-01-31 23:30:26   2025-01-31 23:36:41              NaN
# 3475204         2  2025-01-31 23:33:05   2025-01-31 23:46:21              NaN
# 3475205         2  2025-01-31 23:43:55   2025-01-31 23:48:40              NaN
# 3475212         2  2025-01-31 23:00:46   2025-01-31 23:12:08              NaN
# 3475217         2  2025-01-31 23:38:25   2025-01-31 23:46:15              NaN
#
# ...

# %%
len(registros_erroneos)
# Out:
# 170939

# %%
len(registros_erroneos) / len(df) * 100
# Out:
# 4.918788015513235

# %%
registros_erroneos = df[
    (df["tpep_dropoff_datetime"] <= df["tpep_pickup_datetime"]) |
    (df["trip_distance"] < 0) |
    (df["fare_amount"] < 0) |
    (df["total_amount"] < 0) |
    (df["tip_amount"] < 0) |
    (df["tolls_amount"] < 0) |
    (df["passenger_count"] <= 0) |
    (df["PULocationID"].isna()) |
    (df["DOLocationID"].isna())
]

print("Total registros erróneos:", len(registros_erroneos))
print("Porcentaje:", round(len(registros_erroneos) / len(df) * 100, 4), "%")
# Out:
# Total registros erróneos: 170939
# Porcentaje: 4.9188 %
